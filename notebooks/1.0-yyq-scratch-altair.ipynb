# %% [markdown]
# # About
#
# test if we can use Altair for data viz
#
# * https://altair-viz.github.io/getting_started/overview.html
# * https://anaconda.org/conda-forge/altair

# %%
import numpy as np
import pandas as pd

import altair as alt

# %%
# loads data
train_pd = pd.read_csv("../data/raw/train.csv.zip", compression="zip")
test_pd = pd.read_csv("../data/raw/test.csv.zip", compression="zip")

# %%
alt.Chart(train_pd).mark_point().encode(
    alt.X("X", bin=True),
    y='count()',
)
# Out:
# ---------------------------------------------------------------------------
# MaxRowsError                              Traceback (most recent call last)
# ~\Anaconda3\envs\w207re-final-proj\lib\site-packages\altair\vegalite\v2\api.py in to_dict(self, *args, **kwargs)
#     400         copy = self.copy()
#     401         original_data = getattr(copy, 'data', Undefined)
# --> 402         copy.data = _prepare_data(original_data, context)
#     403
#     404         if original_data is not Undefined:
#
# ~\Anaconda3\envs\w207re-final-proj\lib\site-packages\altair\vegalite\v2\api.py in _prepare_data(data, context)
#      82     # convert dataframes to dict
#      83     if isinstance(data, pd.DataFrame):
# ---> 84         data = pipe(data, data_transformers.get())
#      85
#      86     # convert string input to a URLData
#
# ~\Anaconda3\envs\w207re-final-proj\lib\site-packages\toolz\functoolz.py in pipe(data, *funcs)
#     550     """
#     551     for func in funcs:
# ...
